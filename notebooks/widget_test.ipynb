# %% [markdown]
# # Logtalk Widget Communication Test
#
# This notebook contains minimal examples to test widget communication between JavaScript and the Logtalk kernel.

# %%
% Test simple kernel communication
true.
# Out:
# true

# %%
% Create a simple text widget
jupyter::create_text_input(test_input, 'Test:', 'initial value').
# Out:
#
#         <script type="text/javascript">
#         // Initialize kernel interface
#         window.JUPYTER_KERNEL = {"id": "25787c21-4dfd67898989a7f6c4e725d5", "name": "logtalk", "session_id": "25787c21-4dfd67898989a7f6c4e725d5", "execution_state": "idle"};
#
#         // Initialize global message queue if it doesn't exist
#         if (!window.JUPYTER_MESSAGE_QUEUE) {
#             window.JUPYTER_MESSAGE_QUEUE = {
#                 promises: new Map(),  // For tracking individual message promises
#                 queue: [],           // For queuing messages
#                 processing: false,   // Flag to prevent concurrent processing
#
#                 // Add a new message to the queue
#                 async add(code, options = {}) {
#                     return new Promise((resolve, reject) => {
#                         const msgId = 'exec_' + Date.now() + '_' + Math.random().toString(36).substr(2, 9);
#                         this.promises.set(msgId, { resolve, reject });
# ...

# %%
% Enable widget debugging
jupyter_widget_handling::debug_widgets.
# Out:
# === Widget Debug Information ===
# Widget test_input: Type=text_input, Value=initial value
# === End Widget Debug ===
# true
